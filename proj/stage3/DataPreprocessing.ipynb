# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
dataset = pd.read_csv("Data_before.csv", na_values=['None', ' nan'])

# %%
dataset.columns
# Out:
# Index(['time', 'solarRadiation', 'uvHigh', 'winddirAvg', 'humidityHigh',
#        'humidityLow', 'humidityAvg', 'qcStatus', 'tempHigh', 'tempLow',
#        'tempAvg', 'windspeedHigh', 'windgustLow', 'windspeedAvg', 'dewptHigh',
#        'dewptLow', 'dewptAvg', 'windchillHigh', 'windchillAvg',
#        'heatindexHigh', 'heatindexLow', 'heatindexAvg', 'pressureMax',
#        'pressureMin', 'pressureTrend', 'precipRate', 'precipTotal', 'power'],
#       dtype='object')

# %%
dataset.head()
# Out:
#        time  solarRadiation  uvHigh  winddirAvg  humidityHigh  humidityLow  \
# 0  14:20:00          677.62     7.0       182.0          24.0         24.0
# 1  14:29:00          627.70     7.0       195.0          24.0         24.0
# 2  14:34:00          617.31     7.0       129.0          24.0         23.0
# 3  14:39:00          608.13     6.0       108.0          24.0         23.0
# 4  14:44:00          582.57     6.0        87.0          25.0         24.0
#
#    humidityAvg  qcStatus  tempHigh  tempLow     ...      windchillAvg  \
# 0         24.0        -1      66.0     66.0     ...              66.0
# 1         24.0        -1      65.0     65.0     ...              65.0
# 2         23.0        -1      68.0     66.0     ...              67.0
# 3         23.0        -1      68.0     67.0     ...              67.0
# 4         24.0        -1      67.0     66.0     ...              66.0
#
#    heatindexHigh  heatindexLow  heatindexAvg  pressureMax  pressureMin  \
# 0           66.0          66.0          66.0        30.06        30.06
# 1           65.0          65.0          65.0        30.06        30.05
# 2           68.0          66.0          67.0        30.06        30.05
# 3           68.0          67.0          67.0        30.06        30.05
# 4           67.0          66.0          66.0        30.06        30.05
#
#    pressureTrend  precipRate  precipTotal       power
# 0            NaN         0.0          0.0 -422.322232
# 1           0.60         0.0          0.0 -403.168317
# 2          -0.15         0.0          0.0         NaN
# 3           0.00         0.0          0.0 -389.270927
# 4          -0.15         0.0          0.0 -379.477948
#
# [5 rows x 28 columns]

# %%
print('Before removing the nan', dataset.shape)
# Out:
# Before removing the nan (6264, 28)

# %%
dataset = dataset[dataset['power'].notna()]

print('After removing the nan', dataset.shape)
# Out:
# After removing the nan (3465, 28)

# %%
print('the percentage of the zeros in precipRate column' , dataset['precipRate'].isin([0]).sum() / dataset['precipRate'].shape[0])
print('the percentage of the zeros in precipTotal column' , dataset['precipTotal'].isin([0]).sum() / dataset['precipTotal'].shape[0])
# Out:
# the percentage of the zeros in precipRate column 0.9595959595959596
# the percentage of the zeros in precipTotal column 0.8225108225108225

# %%
#Dropping 'precipRate' and 'precipTotal' because it is mostly zero

dataset.drop(['precipRate','precipTotal'], axis=1, inplace=True)

dataset.head()
# Out:
#        time  solarRadiation  uvHigh  winddirAvg  humidityHigh  humidityLow  \
# 0  14:20:00          677.62     7.0       182.0          24.0         24.0
# 1  14:29:00          627.70     7.0       195.0          24.0         24.0
# 3  14:39:00          608.13     6.0       108.0          24.0         23.0
# 4  14:44:00          582.57     6.0        87.0          25.0         24.0
# 5  14:49:00          571.67     6.0        38.0          24.0         24.0
#
#    humidityAvg  qcStatus  tempHigh  tempLow     ...      dewptAvg  \
# 0         24.0        -1      66.0     66.0     ...          28.0
# 1         24.0        -1      65.0     65.0     ...          28.0
# 3         23.0        -1      68.0     67.0     ...          29.0
# 4         24.0        -1      67.0     66.0     ...          29.0
# 5         24.0        -1      66.0     66.0     ...          28.0
#
#    windchillHigh  windchillAvg  heatindexHigh  heatindexLow  heatindexAvg  \
# 0           66.0          66.0           66.0          66.0          66.0
# 1           65.0          65.0           65.0          65.0          65.0
# 3           68.0          67.0           68.0          67.0          67.0
# 4           67.0          66.0           67.0          66.0          66.0
# 5           66.0          66.0           66.0          66.0          66.0
#
#    pressureMax  pressureMin  pressureTrend       power
# 0        30.06        30.06            NaN -422.322232
# 1        30.06        30.05           0.60 -403.168317
# 3        30.06        30.05           0.00 -389.270927
# 4        30.06        30.05          -0.15 -379.477948
# 5        30.05        30.04          -0.15 -370.189019
#
# [5 rows x 26 columns]

# %%
missing_columns = [col for col in dataset.columns if dataset[col].isna().any()]
missing_columns
# Out:
# ['solarRadiation',
#  'uvHigh',
#  'winddirAvg',
#  'humidityHigh',
#  'humidityLow',
#  'humidityAvg',
#  'tempHigh',
#  'tempLow',
#  'tempAvg',
#  'windspeedHigh',
#  'windgustLow',
#  'windspeedAvg',
#  'dewptHigh',
#  'dewptLow',
#  'dewptAvg',
#  'windchillHigh',
#  'windchillAvg',
#  'heatindexHigh',
#  'heatindexLow',
#  'heatindexAvg',
#  'pressureTrend']

# %%
smp = SimpleImputer(missing_values=np.nan, strategy='mean')
dataset[missing_columns] = smp.fit_transform(dataset[missing_columns])

# %%
print('Total number of missing values ', dataset.isna().any().sum())
print('The final shape of the dataset ', dataset.shape)
# Out:
# Total number of missing values  0
# The final shape of the dataset  (3465, 26)

# %%
dataset.head()
# Out:
#        time  solarRadiation  uvHigh  winddirAvg  humidityHigh  humidityLow  \
# 0  14:20:00          677.62     7.0       182.0          24.0         24.0
# 1  14:29:00          627.70     7.0       195.0          24.0         24.0
# 3  14:39:00          608.13     6.0       108.0          24.0         23.0
# 4  14:44:00          582.57     6.0        87.0          25.0         24.0
# 5  14:49:00          571.67     6.0        38.0          24.0         24.0
#
#    humidityAvg  qcStatus  tempHigh  tempLow     ...      dewptAvg  \
# 0         24.0        -1      66.0     66.0     ...          28.0
# 1         24.0        -1      65.0     65.0     ...          28.0
# 3         23.0        -1      68.0     67.0     ...          29.0
# 4         24.0        -1      67.0     66.0     ...          29.0
# 5         24.0        -1      66.0     66.0     ...          28.0
#
#    windchillHigh  windchillAvg  heatindexHigh  heatindexLow  heatindexAvg  \
# 0           66.0          66.0           66.0          66.0          66.0
# 1           65.0          65.0           65.0          65.0          65.0
# 3           68.0          67.0           68.0          67.0          67.0
# 4           67.0          66.0           67.0          66.0          66.0
# 5           66.0          66.0           66.0          66.0          66.0
#
#    pressureMax  pressureMin  pressureTrend       power
# 0        30.06        30.06       0.001357 -422.322232
# 1        30.06        30.05       0.600000 -403.168317
# 3        30.06        30.05       0.000000 -389.270927
# 4        30.06        30.05      -0.150000 -379.477948
# 5        30.05        30.04      -0.150000 -370.189019
#
# [5 rows x 26 columns]

# %%
dataset.to_csv("cleanedData.csv", header = True, index = False)
